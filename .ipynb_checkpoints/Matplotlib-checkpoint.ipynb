# %% [markdown]
# ##### 10-july-2021

# %% [markdown]
# # Data visualization in Python

# %% [raw]
# -pillow
# -matplotlib
# -seaborn

# %%
from PIL import Image
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### PILLOW

# %%
im = Image.open('python.jpeg')

# %%
imshow(im)

# %%
im45 = im.rotate(45)

# %%
imshow(im45)

# %%
im_norm = im.rotate(-45)

# %%
im_norm = im.rotate(0)

# %%
imshow(im_norm)

# %%
im.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
im.format
# Out:
# 'JPEG'

# %%
im.mode
# Out:
# 'RGB'

# %%
im.size
# Out:
# (1200, 900)

# %%
im.width
# Out:
# 1200

# %%
im.height
# Out:
# 900

# %%
im.info
# Out:
# {'jfif': 257,
#  'jfif_version': (1, 1),
#  'dpi': (72, 72),
#  'jfif_unit': 1,
#  'jfif_density': (72, 72)}

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x900 at 0x7F6816B877F0>

# %%
im.save('py.png')

# %% [markdown]
# #### Creating thumbnail

# %%
###im.thumbnail([90,90])
im.save('thumb.png')

# %%
im.show()

# %%
im2 = Image.open('tiger.jpg')

# %%
im2.show()

# %%
im.show()

# %%
im.size
# Out:
# (1200, 900)

# %%
im2.size
# Out:
# (300, 168)

# %% [markdown]
# #### Combining images

# %%
combined_img = Image.new('RGB',(2*im.width,im.height),(250,250,250))#(250,250,250) - corner color
combined_img.paste(im,(0,0))
combined_img.paste(im2,(im.width,0))
combined_img.save('comb.png','JPEG')
imshow(combined_img)

# %% [markdown]
# #### Blur

# %%
from PIL import ImageFilter
tiger = im2

blur_tiger = tiger.filter(ImageFilter.BLUR)
blur_tiger.save('blur_tiger.png')
blur_tiger.show()

# %% [raw]
# - crop
# - resize
# - boxfilter
# - watermark
# - gaussian filter
# -

# %% [markdown]
# ## Matplotlib

# %%
import numpy as np

# %%
x = np.linspace(-np.pi,np.pi,256,endpoint=True)

# %%
x.shape
# Out:
# (256,)

# %%
C,S = np.cos(x),np.sin(x)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,C)

# %%
plt.plot(x,S)

# %%
plt.plot(x,C)
plt.plot(x,S)
plt.show()

# %%
plt.figure(figsize = (10,6),dpi = 80) 
plt.plot(x,C,color = 'blue', linewidth = 3.0,linestyle = "-")
plt.plot(x,S,color = 'red', linewidth = 3.0,linestyle = "-")
plt.show()

# %%
x.min()
# Out:
# -3.141592653589793

# %%
plt.figure(figsize = (10,6),dpi = 80)

plt.plot(x,C,color = 'blue', linewidth = 3.0,linestyle = "-")
plt.plot(x,S,color = 'red', linewidth = 3.0,linestyle = "-")

plt.xlim(-0.4,0.4)#x limits
plt.xticks(np.linspace (-4,4,9,endpoint=True))#x ticks

plt.ylim(-1.0,1.0)#y limits
plt.yticks(np.linspace(-1,1,5,endpoint=True))#y ticks

plt.show()

# %%
plt.figure(figsize = (10,6),dpi = 80)

plt.plot(x,C,color = 'blue', linewidth = 3.0,linestyle = "-")
plt.plot(x,S,color = 'red', linewidth = 3.0,linestyle = "-")

plt.xlim(-0.4,0.4)#x limits
plt.xticks([-np.pi,-np.pi/2,0,np.pi/2,np.pi])#y ticks

plt.ylim(-1.0,1.0)#y limits
plt.yticks(np.linspace(-1,1,5,endpoint=True))#y ticks

plt.show()

# %%
plt.figure(figsize = (10,6),dpi = 80)

plt.plot(x,C,color = 'blue', linewidth = 3.0,linestyle = "-")
plt.plot(x,S,color = 'red', linewidth = 3.0,linestyle = "-")

plt.xlim(-4.0,4.0)#x limits
plt.xticks([-np.pi,-np.pi/2,0,np.pi/2,np.pi],#y ticks
           #latex formatting of scientific symbols
          [r'$-\pi$',r'$-\pi/2$',r'$0$',r'$+\pi/2$',r'$+\pi$'])

plt.ylim(-1.0,1.1)#y limits
plt.yticks(np.linspace(-1,1,5,endpoint=True))#y ticks

plt.show()

# %%
plt.figure(figsize = (10,6),dpi = 80)

plt.plot(x,C,color = 'blue', linewidth = 3.0,linestyle = "-",label ="Cosine")
plt.plot(x,S,color = 'red', linewidth = 3.0,linestyle = "-",label ="Sine")

#set legend
plt.legend(loc = 'upper left',frameon =False)


plt.xlim(-4.0,4.0)#x limits
plt.xticks([-np.pi,-np.pi/2,0,np.pi/2,np.pi],#y ticks
           #latex formatting of scientific symbols
          [r'$-\pi$',r'$-\pi/2$',r'$0$',r'$+\pi/2$',r'$+\pi$'])

plt.ylim(-1.0,1.1)#y limits
plt.yticks(np.linspace(-1,1,5,endpoint=True))#y ticks

plt.show()

# %%
ax = plt.subplot(111)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.yaxis.set_ticks_position('left')

# %%
plt.figure(figsize=(10,6), dpi=80)

ax = plt.subplot(111)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.yaxis.set_ticks_position('left')

plt.plot(x, C,  color='blue', linewidth=3.0, linestyle="-", label="cosine")
plt.plot(x, S, color='red', linewidth=3.0, linestyle="-", label="sin")

## set x limits
plt.xlim(-4.0, 4.0)

# set x ticks
# latex formating of scientific symbols
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

# set y limits
plt.ylim(-1.0, 1.1)

# y ticks
plt.yticks(np.linspace(-1, 1, 6, endpoint=True))

t = 2 * np.pi / 3
plt.plot([t,t], [0, np.cos(t)],  color='blue', linewidth=3.0, linestyle="-")
plt.scatter([t,  ], [np.cos(t), ], 50, color='blue')
plt.annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
                    xy=(t, np.sin(t)), xycoords='data',
                    xytext=(+15, +10), textcoords='offset points', fontsize=14,
                    arrowprops=dict(arrowstyle="->", connectionstyle="arc3, rad=.2"))

plt.plot([t,t], [0, np.sin(t)], color='red', linewidth=3.0, linestyle="-")
plt.scatter([t,  ], [np.sin(t), ], 50, color='red')

plt.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',
                    xy=(t, np.cos(t)), xycoords='data',
                    xytext=(-90, -50), textcoords='offset points', fontsize=14,
                    arrowprops=dict(arrowstyle="->", connectionstyle="arc3, rad=.2"))
# set legend
plt.legend(loc='upper left', frameon=False)

plt.show()

# %% [raw]
# -bar/horizontal bar graph
# -heatmap /2D /3D
# -scatterplot
# -violin plots
# -bubbles
# -polar

# %% [markdown]
# ##### 11-july-2021

# %% [markdown]
# #### Bar plot

# %%
import numpy as np
import matplotlib.pyplot as plt


#create sample dat set
data = {'C':20,'C++':15,'Java':30,'Python':45}

courses = list (data.keys())
values = list(data.values())

fig = plt.figure(figsize=(10,6))

#create the plot
plt.bar(courses, values,color='skyblue',width=0.5)
plt.xlabel("our courses")
plt.ylabel("no of session")
plt.title("our awesome matplotlib")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


#create sample dat set
data = {'C':20,'C++':15,'Java':30,'Python':45}

courses = list (data.keys())
values = list(data.values())

fig = plt.figure(figsize=(10,6))

#create the plot(horizontal bar)
plt.barh(courses, values,color='olive')
plt.xlabel("our courses")
plt.ylabel("no of session")
plt.title("our awesome matplotlib")
plt.show()

# %%
import pandas as pd

data = pd.read_csv("../LED_usage_survey_data.csv")
data.head()
# Out:
#              Timestamp          Name    Age  LED usage         Student  \
# 0  08/07/2021 12:02:27       nithish  18-23          8  under-graduate
# 1  08/07/2021 14:38:06  Rithani K. S  18-23          2  under-graduate
# 2  08/07/2021 14:38:58       Mythili  18-23          5  under-graduate
# 3  08/07/2021 14:41:07    kushal sai  18-23          8  under-graduate
# 4  08/07/2021 14:42:18          Neil  18-23          8  under-graduate
#
#    Academic performance  Mobile Phones usage  Laptops usage  \
# 0                     4                    2              8
# 1                     4                    6              2
# 2                     4                    5              1
# 3                     3                    5              4
# 4                     4                    4              4
#
#    Desktop Pc's usage  Tablets or iPads usage  Television usage  \
# 0                   0                       0                 1
# 1                   0                       0                 1
# 2                   0                       1                 1
# 3                   0                       0                 1
# 4                   0                       0                 1
#
#   Other devices usage  Educational purpose  Professional work purpose  \
# 0                 NaN                    9                          3
# 1                 No                     8                          5
# 2                 NaN                    3                          1
# 3                None                    2                          0
# 4                 NaN                    3                          0
#
#    TIME PASS purpose  GAMING purpose Other purposes Eye sight problem  \
# 0                  0               0            NaN               Yes
# 1                  2               0             No                No
# 2                  2               1            NaN             Maybe
# 3                  4               3     Ps4- 3 hrs               Yes
# 4                  5               0            NaN               Yes
#
#   wearing power glass Suffering headaches
# 0                 Yes              Rarely
# 1                  No        NO headaches
# 2                  No              Rarely
# 3                 Yes              Weekly
# 4                 Yes              Rarely

# %%
name = data['Name'].head(10)
lapusg =data['Laptops usage'].head(10)

fig = plt.figure(figsize = (10,8))
plt.bar(name,mblusg)
plt.show()

# %%
name = data['Name'].head(10)
mblusg =data['Mobile Phones usage'].head(10)

fig,ax= plt.subplots(figsize = (16,9))

#horizontal bar plot
ax.barh(name,mblusg)

#remove plot spines
for side in ['top','bottom','left','right']:
    ax.spines[side].set_visible(False)

#remove x,Y ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

#add padding
ax.xaxis.set_tick_params(pad=5)
ax.yaxis.set_tick_params(pad=5)

#add grid lines
ax.grid(b=True,color='gray',linestyle='-',linewidth=0.5,alpha=0.2)

ax.invert_yaxis()

#add annotations
for i in ax.patches:
    plt.text(i.get_width()+0.2,i.get_y()+0.5,str(round(i.get_width(),2)),
             fontsize=12,fontweight='bold',color='gray')

#add watermark
fig.text(0.9,0.15,'Nithish kumar',fontsize=16,color='lightgray',ha='right',va='bottom',alpha=0.8)

ax.set_title('Students with their usage of phones')

#plt.bar(name,lapusg)
plt.show()

# %% [markdown]
# ### 2D heatmap

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_h = np.random.random((12,12))
plt.imshow(data_h,cmap='autumn',interpolation='nearest')
plt.title('2D histogram in python')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_h = np.random.random((12,12))
plt.imshow(data_h,cmap='summer',interpolation='nearest')
plt.title('2D histogram in python')
plt.show()

# %% [markdown]
# ### Seaborn

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data_1 = np.random.rand(16,16)
ax= sns.heatmap(data_1,linewidth=0.5,cmap='coolwarm')
plt.title('2D seaborn heatmap in python')
plt.show()

# %% [markdown]
# ##### colormaps
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %% [markdown]
# #### Scatterplot

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-whitegrid")

# %%
x = np.linspace(0,10,30)
y=np.sin(x)

plt.plot(x,y,'o',color='black')

# %%
rng = np.random.RandomState(0)
for marker in ['o','.',',','x','+','v','^','>','<','s','d']:
    plt.plot(rng.rand(5),rng.rand(5),marker,label = "marker='{0}'".format(marker))
    
plt.legend(numpoints = 1)
plt.xlim(0,1.8)
# Out:
# (0.0, 1.8)

# %%
plt.plot(x,y,'-ok')

# %%
plt.plot(x,y,'-p',color='gray',
        markersize = 15,linewidth=4,
        markerfacecolor='white',
        markeredgecolor='gray',
        markeredgewidth=2)

plt.ylim(-1.2,1.2)
# Out:
# (-1.2, 1.2)

# %% [markdown]
# #### Bubble plot

# %%
rng = np.random.RandomState(7)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.randn(100)
sizes = 1000*rng.randn(100)

plt.scatter(x,y,c=colors,s=sizes,alpha=0.3,cmap='viridis')
plt.colorbar()

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris. data.T

plt.scatter(features[0],features[1],alpha=0.3,
           s=100*features[3],c=iris.target,cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')
